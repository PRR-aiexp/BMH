# %%
import scipy.io as spio

file_mat = spio.loadmat("../data/raw/B0054.mat")
 # Ignore MATLAB metadata keys
bat_keys = [k for k in file_mat.keys() if not k.startswith("__")]

if len(bat_keys) != 1:
    raise ValueError(f"Expected 1 battery key, found {battery_keys}")

bkey = bat_keys[0]
print(bkey)


print(file_mat[bkey].dtype)

cyc = file_mat[bkey]['cycle'][0,0]
print(len(cyc))

bat_struct = file_mat[bkey]
print(bat_struct.dtype)
type(bat_struct)
bat_struct.dtype

bat_struct_00 = bat_struct[0,0]
bat_struct_00.dtype.names

cyc = bat_struct_00['cycle']
type(cyc)
cyc.shape
cyc_0 = cyc[0]
type(cyc_0)
cyc_0.dtype.names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/scipy/io/matlab/_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/B0054.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 3
#       1 import scipy.io as spio
# ----> 3 file_mat = spio.loadmat("../data/raw/B0054.mat")
#       4  # Ignore MATLAB metadata keys
#       5 bat_keys = [k for k in file_mat.keys() if not k.startswith("__")]
#
# File /usr/lib/python3/dist-packages/scipy/io/matlab/_mio.py:225, in loadmat(file_name, mdict, appendmat, **kwargs)
#      88 """
# ...

# %%
import os 
import numpy as np
os.getcwd()
os.chdir("..")
os.getcwd()
import pyarrow

# Load battery mat
#key, battery = load_battery_mat("./data/raw/B0054.mat")

# Unwrap battery safely
#battery_struct = unwrap_battery(battery)

# Grab the cycles array
#cycles_array = battery_struct['cycle']

# Inspect the first few cycles
#print("cycles_array type:", type(cycles_array))
#print("cycles_array shape:", cycles_array.shape)
#print("cycles_array ndim:", cycles_array.ndim)

# Inspect the first element
#first_cycle = cycles_array[0]
#print("first_cycle type:", type(first_cycle))

# If it's an array, check its shape
#if isinstance(first_cycle, np.ndarray):
 #   print("first_cycle shape:", first_cycle.shape)

    
    
#battery_struct = unwrap_battery(battery)
#cycles_array = battery_struct['cycle']

# pick first cycle
#cycle = cycles_array[0, 0]
#cycle = unwrap_cycle(cycle)

# inspect 'data' field
#data = cycle['data'][0, 0]
#print("data type:", type(data))
#print("data dtype names:", data.dtype.names)
print("\n+++++++++++++++++ something +++++++++")
# Out:
# +++++++++++++++++ something +++++++++

# %%
import os 
import sys 
import numpy as np
import pyarrow
import fastparquet


from bmhelt.ingest.nasa_loader import unwrap_cycle, unwrap_battery, load_battery_mat, ingest_battery

df = ingest_battery("../data/raw/B0054.mat")
df.head()
df.shape
df["cycle_type"].value_counts()

bronze_path = "../data/bronze/B0054.parquet"
os.makedirs(os.path.dirname(bronze_path), exist_ok=True)
df.to_parquet(bronze_path, index=False)
print("********* done ++++++++")
# Out:
# ********* done ++++++++
